# %% [markdown]
# Problem Statement:
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
#
# **HR Analytics**
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
# **Attrition in HR**
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
#
# **Attrition affecting Companies**
#
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %%
#importing essential libraries
import pandas as pd #pandas library
import numpy as np #numpy library

import seaborn as sns #seaborn
import matplotlib.pyplot as plt #matplotlib
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore') #warnings

# %%
#importing the dataset
data=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %% [markdown]
# **this dataset has 1470 rows and 35 columns**

# %%
#printing column names
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#checking for null values in dataset
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# **There are no null values in dataset**

# %%
#checkimg for duplicates in dataset

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are no duplicate entries in dataset**

# %%
#checking for unique values in Label
data['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(data['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# **It can be seen from above plot that most of the employees may be working in this company while 237 employees maybe looking to find other job**

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# **Most employees are in the age are in the age group of 29-40 years. youngest employees are of 18 years while older working employee is nearing to his retirement i.e. 60 years old.**

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['BusinessTravel'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# **Observations**
# - From above plot it can be seen that there are 3 types of employees that travel for business purpose.
# - Most of the employees travel rarely for business purposes, while >200 employees travel frequently while least number of employees never travel or are stationed for desk job.

# %%
sns.histplot(data['DailyRate'])
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Count'>

# %% [markdown]
# **Observation**
# - In above plot we can see the daily rates of employees.

# %%
sns.countplot(data['Department'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# Observation:
# - As seen in plot there are 3 departments in this company wherein most people are working in R&D, while around >400 people work in Sales. Least number of employees work in HR department.

# %%
sns.countplot(data['DistanceFromHome'])
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='count'>

# %% [markdown]
# Observation:
# - Most of the employees stay nearby from their workplace i.e. 1-3 km range. The max, distance travelled by employees is 29kms to travel to office.

# %%
sns.countplot(data['Education'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
#  Observation:
# - There are 5 classes of education in which employees are rated. Class 3 has most number of employees while class 5 has least number of employees.

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['EducationField'])
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# Observation:
# - Most of the employees work in LifeSciences dept., while very few emploees work in HR depts.
# - Other fields of work are Medical, marketing, technical degrees and Others.

# %%
sns.histplot(data['EmployeeCount'])
# Out:
# <AxesSubplot:xlabel='EmployeeCount', ylabel='Count'>

# %%
data['EmployeeCount'].value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %% [markdown]
# Observation:
# - All the employees have same employee count that is 1.

# %%
sns.countplot(data['EmployeeNumber'])
# Out:
# <AxesSubplot:xlabel='EmployeeNumber', ylabel='count'>

# %%
data['EmployeeNumber'].unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068], dtype=int64)

# %% [markdown]
# Observation:
# - Employee numbers can be ID numbers provided to employees when they join company, this can be said because though there are 1470 employee details, the employee number goes upto 2068 as seen above.

# %%
sns.countplot(data['EnvironmentSatisfaction'])
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %% [markdown]
# Observations:
# - Most number of employees have selected 3 and 4 as the environment satisfaction while less equal number of employees fall under 1 and 2.

# %%
sns.countplot(data['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Observations:
# - There are more number of male employees working than female ones.

# %%
sns.countplot(data['JobInvolvement'])
# Out:
# <AxesSubplot:xlabel='JobInvolvement', ylabel='count'>

# %% [markdown]
# Observations:
# - Most number of employees are involved in their jobs in class 3 category, while least number of employees are in class 1 category.

# %%
sns.countplot(data['JobLevel'])
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# Observations:
# - Highest number of employees are at their entry level jobs. <50 employees are at their highest position of job level.

# %%
plt.figure(figsize=(20,4))
sns.countplot(data['JobRole'])
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='count'>

# %% [markdown]
# Observation:
# - The above plot shows thr job roles of employees in this company.
# - Highest number of employees have a job role as Sales Executive followed by Research Scientist and lab technicican.
# - The least number of employees has job role in Human resources.

# %%
sns.countplot(data['JobSatisfaction'])
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='count'>

# %% [markdown]
# Observation:
# - Most of the employees are highly satisfied with the job they are working in, while close to 300 employees are not satisfied with their job.

# %%
sns.countplot(data['MaritalStatus'],hue=data['Gender'])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# Observation:
# - male supersedes in number in all 3 above categories.
# - Most number of people working are married foloowed by single people. Over 300 people working are divorced.

# %%
sns.swarmplot(data['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %% [markdown]
# Observation:
# - Most of the people working have salaries in range from <2500USD to 7500 USD. The max. salary received by employees is close to 20000USD per month.

# %%
sns.countplot(data['NumCompaniesWorked'])
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='count'>

# %% [markdown]
# Observation:
# - Most employees have worked in 1 company before joining this company, while there are 200 employees who are freshers.
# - There are >50 employees who have worked in >9 companies before joining present company.

# %%
sns.countplot(data['Over18'])
# Out:
# <AxesSubplot:xlabel='Over18', ylabel='count'>

# %% [markdown]
# All the employees are over the age of 18

# %%
sns.countplot(data['OverTime'],hue=data['Gender'])
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# Observation:
# - Most of the employees dont do overtime, and it can be seen that females also do overtime but are in less number then men.

# %%
sns.countplot(data['PercentSalaryHike'])
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %% [markdown]
# Observation:
# - From the plot it can be seen that most of the employees have received salary hike in range 11-14% while very few employees have got 25% salary hike.

# %%
sns.countplot(data['PerformanceRating'],hue=data['MaritalStatus'])
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %% [markdown]
# Observation:
# - Most of the employees have received performance rating of 3 while only 200 employees received performance rating of 4.

# %%
sns.countplot(data['StandardHours'])
# Out:
# <AxesSubplot:xlabel='StandardHours', ylabel='count'>

# %% [markdown]
# Observation:
# - ALl employees have to work standard 80 hours.

# %%
plt.figure(figsize=(15,4))
sns.countplot(data['TotalWorkingYears'])
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %% [markdown]
# Observations:
# - It can be seen from the plot that most number of employees are working for almost 10 years, while there are some employees who are working for over 40 years.

# %%
sns.countplot(data['YearsInCurrentRole'])
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='count'>

# %% [markdown]
# Observation:
# - It can be seen from the plot that most employees are in current job role for over 2 years while few employees are in their present job role for past 18 years

# %%
sns.countplot(data['YearsSinceLastPromotion'])
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='count'>

# %% [markdown]
# Observation:
# - It can be seen that most of the employees have not received promotion in for past less than a year. while very few employees have not received promotion for past>13 years.

# %%
sns.countplot(data['YearsWithCurrManager'])
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %% [markdown]
# Observation:
# - Most of the employees working are under current manager for >2 years. While some new joinees are under a manager for < a year. Very few employees are working under same manager for past >15 years.

# %%
sns.swarmplot(x='Age',y='OverTime',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='OverTime'>

# %% [markdown]
# The above plot shows that the most number of people who dont get overtime are the people who leave company while the employees whi get overtime has less chances of attrition.

# %%
sns.scatterplot(x='BusinessTravel',y='Age',data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Age'>

# %% [markdown]
# From the above plot it can be seen that the employees who travel frequntly have higher chances of attrition.

# %%
sns.swarmplot(x='Department',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - It seems from the plot that more chances of attrition are from employees working in HR dept.

# %%
sns.swarmplot(x='DistanceFromHome',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - From the plot it can be seen that employees who are staying far away from workplace have higher chances of attrition from company.

# %%
plt.figure(figsize=(15,4))
sns.swarmplot(x='EducationField',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - It can be seen from the plot lower number of people from HR and Other departments have chance of attrition compared to other departments.

# %%
sns.barplot(x='EnvironmentSatisfaction',y='Attrition',data=data,hue="Gender")
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - Males have higher chances of attrition wrt to females.
# - females which has chances of attrition have rated working environment lower compared to women who are satisfied with working envirom=nment.
# - Same goes for males implying that if you have good working environment, then chances are people dont tend to change their job often.

# %%
sns.swarmplot(x='DistanceFromHome',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - less number of employees have chance of attrition for varying hourly rates or no matter what hourly rates they get

# %%
sns.swarmplot(x='JobLevel',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - It can be seen from above plot that less number of employees who reach job levels of >4 have chanve of attrition

# %%
plt.figure(figsize=(18,4))
sns.swarmplot(x='JobRole',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - It can be seen from the plot that employees working as Healthcare representatve, manager and research director, all 3 has very low in number for attrition from company.
# - Maximun attrition is seen in Sales Execitive.

# %%
sns.swarmplot(x='JobSatisfaction',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - There is no conclusive relationship between above plot.

# %%
sns.swarmplot(x='MonthlyIncome',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - Very less number of employeessss has chance of attrition whose monthly income goes above 12500USD. Person earning less salaries has higher chance of attrition.

# %%
sns.swarmplot(x='NumCompaniesWorked',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - In this company the persons who have worked in past 8 companies has higher chance of attrition.

# %%
sns.swarmplot(x='OverTime',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - There is no possible relationship can be seen in overtime and Attrition.

# %%
sns.swarmplot(x='PercentSalaryHike',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - It can be seen that less number of employees have chance of attrition if they get good salary hike i.e.>20%.

# %%
sns.swarmplot(x='PerformanceRating',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - The above plot shows relationship betwweem Attrition and Performace Rating.

# %%
sns.swarmplot(x='TotalWorkingYears',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Attrition'>

# %% [markdown]
# Observations:
# - If the total number of working years is more than 15-20 years then the attrition is less compared to newly joined or <10 years of working employees.

# %%
sns.swarmplot(x='YearsInCurrentRole',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - If the employees are in same role for >5 years then less chances of atrrition within company.

# %%
sns.swarmplot(x='YearsSinceLastPromotion',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Attrition'>

# %% [markdown]
# observation:
# - It can be seen from above plot that of employees who got promotions within first 2 years have higher chances of attrition.

# %%
sns.swarmplot(x='YearsWithCurrManager',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - It can be seen from above plot that employees working for >7.5 years under current manager will be staying and working in that comapany.

# %%
sns.swarmplot(x='MaritalStatus',y='Attrition',data=data)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Attrition'>

# %% [markdown]
# Observation:
# - It can be seen from the above plot there is no particular relation for employees attrition from company with respect to their marital status.

# %%
#checking for value count in Employee count column
data['EmployeeCount'].value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %% [markdown]
# **It can be seen that for all the employees the value is only 1, hence this column wont be helping in making ML model. Hence dropping this column will be a better option.**

# %%
#checking for value count in Employee number column
data['EmployeeNumber'].value_counts()
# Out:
# 1       1
# 1391    1
# 1389    1
# 1387    1
# 1383    1
#        ..
# 659     1
# 657     1
# 656     1
# 655     1
# 2068    1
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %% [markdown]
# **The above data looks like the employee serial numbers provided to employees when they join the company. This  serial number data is not useful to us in predicting attrition for the comapany. Hence deleting this column will be a better option.**

# %%
data['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# **The data suggests that all the persons working are over the age of 18 years. Since the data is same for all employees this will not help us in prediction attrition in company, hence this column will be dropped.**

# %%
data['StandardHours'].value_counts()
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %% [markdown]
# **Since all the employees have to work Standard Hours i.e. 80 hours hence this will not help us in prediction attrition in company, hence this column will be dropped.**

# %% [markdown]
# # dropping columns that are not useful in ML model

# %%
data=data.drop(['EmployeeCount','EmployeeNumber','StandardHours','Over18'],axis=1)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 31)

# %% [markdown]
# Since 4 columns are dropped shape of dataset dropped to 31 columns from 35 rows.

# %% [markdown]
# # Encoding the dataset using label encoder

# %% [markdown]
#  **Encoding the Attrition,Business Travel, Department, EducationField, Gender, JoBLevel, MaritalStatus and Overtime.**

# %%
#importing library for label encoder

from sklearn.preprocessing import LabelEncoder

label_enc=LabelEncoder()

# %%
#transforming the data
df1=label_enc.fit_transform(data['Attrition'])
df2=label_enc.fit_transform(data['BusinessTravel'])
df3=label_enc.fit_transform(data['Department'])
df4=label_enc.fit_transform(data['EducationField'])
df5=label_enc.fit_transform(data['Gender'])
df6=label_enc.fit_transform(data['JobLevel'])
df7=label_enc.fit_transform(data['MaritalStatus'])
df8=label_enc.fit_transform(data['OverTime'])
df9=label_enc.fit_transform(data['JobRole'])

# %%
#saving the encoded data into original dataframe columns
data['Attrition']=df1
data['BusinessTravel']=df2
data['Department']=df3
data['EducationField']=df3
data['Gender']=df4
data['JobLevel']=df5
data['MaritalStatus']=df7
data['OverTime']=df8
data['JobRole']=df9

# %%
data.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.522140          1               2   0.759289           2
# 1  1.276411          0               1  -1.334597           1
# 2  0.102091          1               2   1.340365           1
# 3 -0.353971          0               1   1.379936           1
# 4 -1.123755          0               2  -0.453941           1
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0         -1.494085          2               2                        2
# 1          0.243416          1               1                        3
# 2         -1.031215          2               1                        4
# 3         -0.700347          4               1                        4
# 4         -1.031215          1               1                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
data.describe()
# Out:
#                 Age    Attrition  BusinessTravel     DailyRate   Department  \
# count  1.470000e+03  1470.000000     1470.000000  1.470000e+03  1470.000000
# mean  -8.650865e-16     0.161224        1.607483  1.795616e-16     1.260544
# std    1.000340e+00     0.367863        0.665455  1.000340e+00     0.527792
# min   -2.565934e+00     0.000000        0.000000 -1.955086e+00     0.000000
# 25%   -7.243219e-01     0.000000        1.000000 -7.901739e-01     1.000000
# 50%   -8.279093e-03     0.000000        2.000000  7.073627e-02     1.000000
# 75%    7.205620e-01     0.000000        2.000000  8.799437e-01     2.000000
# max    2.172817e+00     1.000000        2.000000  1.600263e+00     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count      1.470000e+03  1470.000000     1470.000000              1470.000000
# mean      -4.083468e-16     2.912925        1.260544                 2.721769
# ...

# %% [markdown]
# Observation:
# - Age:It can be seen most of the employees working in this company are in age gap of 28-45 years.
# - The highest amount provided daily to employees is 1499 while least is 102 per day.
# - The maximum years at which a employee is working in his current role is for 18 years.
# - The maximum time employees are working under their current maanager is for 17 years.
# - Most of the columns are categorical in nature.

# %%
#plotting the correlation matrix
plt.figure(figsize=(25,25))
corr=(data.corr())
sns.heatmap(corr,annot=True)
plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# # Note
# I take 75% relationship within features for them to look it as multicollinear.
#
# **Observations:**
# - PercentSalaryHike and PerformanceRating is related at 77%.
# - TotalWorkingYears and MonthlyIncome is related at 77%.
# - YearsWithCurrManager and YearsAtCompany is related at 76%.
# - YearsInCurrentRole and YearsAtCompany is related at 76%.

# %% [markdown]
# **Plotting scatter plots to confirm multicollinearity**

# %%
sns.scatterplot(x='PercentSalaryHike',y='PerformanceRating',data=data)
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='PerformanceRating'>

# %% [markdown]
# Observation:
# - Employees received salary hike of upto 19% if theie performance rating was 3; while salary hike of >20% or more if performace rating is 4.

# %%
sns.scatterplot(x='TotalWorkingYears',y='MonthlyIncome',data=data)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='MonthlyIncome'>

# %% [markdown]
# Observation:
# - The above plot shows that as working years increases income also increases

# %%
sns.scatterplot(x='YearsWithCurrManager',y='YearsAtCompany',data=data)
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='YearsAtCompany'>

# %% [markdown]
# Observation:
# - This plot shows that there is positive relation between years at company and years with current manager.

# %%
sns.scatterplot(x='YearsInCurrentRole',y='YearsAtCompany',data=data)
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='YearsAtCompany'>

# %% [markdown]
# Observation:
# - This plot shows that there is positive relation between years at company and years in current role.

# %%
data.skew()
# Out:
# Age                        -0.007603
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.196160
# Department                  0.172231
# DistanceFromHome           -0.007468
# Education                  -0.289681
# EducationField              0.172231
# EnvironmentSatisfaction    -0.321654
# Gender                      0.172231
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.550371
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               0.032831
# MonthlyRate                -0.184087
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears          -0.010653
# ...

# %%
features=['Age','DailyRate','DistanceFromHome','MonthlyIncome','MonthlyRate','TotalWorkingYears',
          'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in features:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# # All the columns are highly skewed, hence removing their skewness using POWER TRANSFORMER

# %%
#importing library
from sklearn.preprocessing import PowerTransformer

scaler=PowerTransformer(method='yeo-johnson') #using yeo-johnson method to transform

# %%
#transforming the data
data[features]=scaler.fit_transform(data[features])

# %%
#printing features to check for skewness
data[features].skew()
# Out:
# Age                       -0.027493
# DailyRate                 -0.042388
# DistanceFromHome           0.012294
# MonthlyIncome             -0.016555
# MonthlyRate               -0.036478
# TotalWorkingYears         -0.028299
# YearsInCurrentRole        -0.014873
# YearsSinceLastPromotion    0.093579
# YearsWithCurrManager      -0.017367
# dtype: float64

# %%
data.shape
# Out:
# (1470, 31)

# %% [markdown]
# # Checking for outliers in dataset

# %%
#plotting boxplots for dataset to check for outliers

plt.figure(figsize=(20,25))
plotnumber=1

for column in features:
    if plotnumber<= 9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Removal of outliers using z-score method

# %%
from scipy.stats import zscore

# %%
z_score=zscore(data[['Age','DailyRate','DistanceFromHome','MonthlyIncome','MonthlyRate','TotalWorkingYears',
          'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']])

# %%
abs_z_score=np.abs(z_score)

# %%
filtering_entry=(abs_z_score<3).all(axis=1)

# %%
data=data[filtering_entry]

# %%
data.shape
# Out:
# (1470, 31)

# %% [markdown]
# # Looks like there were no outliers present after the data was skewed, hence there is no data loss

# %%
data['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# **Looks like the data is imbalanced as the 1 numbered data is low, hence applying SMOTE technique as data is oversampled**

# %%
#splitting data into features and label
x=data.drop(['Attrition'],axis=1)
y=data['Attrition']

# %%
#importing library for SMOTE
from imblearn.over_sampling import SMOTE
from collections import Counter

sm=SMOTE(0.75)

# %%
x_new,y_new=sm.fit_resample(x,y)
print('The no. of classes before fit',format(Counter(y)))
print('The no. of classes after fit',format(Counter(y_new)))
# Out:
# The no. of classes before fit Counter({0: 1233, 1: 237})
# The no. of classes after fit Counter({0: 1233, 1: 924})

# %%
#new data for label
y_new.value_counts()
# Out:
# 0    1233
# 1     924
# Name: Attrition, dtype: int64

# %% [markdown]
# # Using Principal component Analysis (PCA) to know which features are important to understand dataset.

# %%
#importing libraries for PCA and standard scaler

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
#saving in variable

pca=PCA()

# %%
#scaling features

x_scaled=scaler.fit_transform(x_new)

# %%
#fit and transforming features to PCA

pca.fit_transform(x_scaled)
# Out:
# array([[-9.89399258e-01, -2.38154100e+00,  1.39531859e-01, ...,
#         -3.35066404e-16, -3.36421538e-16,  1.31069147e-17],
#        [-1.42506715e+00,  7.25461943e-01, -6.53136900e-01, ...,
#         -3.25704766e-16, -7.75523844e-17, -2.46397918e-16],
#        [ 2.92067940e+00,  2.08921375e-01,  1.14681346e+00, ...,
#         -2.03739920e-15, -7.86748196e-17,  4.79710433e-17],
#        ...,
#        [ 2.48433465e+00, -2.65958961e-01,  1.36678363e+00, ...,
#         -3.67208164e-16,  2.73343694e-17,  9.05922469e-17],
#        [-7.13048852e-01,  9.35753724e-01,  4.59330710e-01, ...,
#         -1.37505070e-16, -1.56640350e-17,  8.51581299e-18],
#        [ 4.25635104e+00, -6.25036412e-01, -2.13104808e+00, ...,
#          8.12475403e-17, -4.22863793e-17, -8.53338115e-17]])

# %%
#plotting curve to see how many featutes are related

plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('principal components')
plt.ylabel('variance covered')
plt.title('PCA')
plt.show()

# %% [markdown]
# It can be seen at 25 features I am able to cover almost 100% of the data hence dropping remaining features will not matter much.

# %%
#selecting 25 features as the best ones in model building

pca=PCA(n_components=25)
new_comp=pca.fit_transform(x_scaled)

# %%
#creating a dataframe of new features

princi_comp=pd.DataFrame(new_comp,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9',
                                          'PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18',
                                           'PC19','PC20','PC21','PC22','PC23','PC24','PC25'])
princi_comp
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.989399 -2.381541  0.139532  2.046903  0.792865  0.476758  0.289114
# 1    -1.425067  0.725462 -0.653137 -0.457479  0.534384  1.421157 -0.047991
# 2     2.920679  0.208921  1.146813  1.005635 -2.255607 -1.506396 -0.045598
# 3    -0.079829  0.391447 -0.417840 -0.349545 -1.072592  1.134172  0.102327
# 4     0.964732  0.833858  0.533461 -0.300484 -0.402598 -1.320124  1.826026
# ...        ...       ...       ...       ...       ...       ...       ...
# 2152  1.963587 -3.674212 -1.791727  0.487724 -0.048997 -0.287025  1.386193
# 2153  3.047127  4.002929  0.490637  0.428191  0.655111  1.684664 -0.620985
# 2154  2.484335 -0.265959  1.366784  1.147751 -0.246905  1.474265  1.072339
# 2155 -0.713049  0.935754  0.459331 -0.691845 -0.403764  0.997744 -1.478289
# 2156  4.256351 -0.625036 -2.131048 -0.614950 -0.768614 -0.663512  1.689531
#
# ...

# %% [markdown]
# # Model Buiding part

# %%
#Logistic Regression Model
#importing libraries

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
#assigning variable to model
lr=LogisticRegression()

# %%
#finding best random state for model
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(princi_comp,y_new,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_train)
    pred=lr.predict(x_test)
    print('training accuracy is ',(accuracy_score(y_train,y_pred)*100),' for random state ',i)
    print('testing accuracy is ',(accuracy_score(y_test,pred)*100),' for random state ',i)
# Out:
# training accuracy is  84.97217068645641  for random state  0
# testing accuracy is  82.77777777777777  for random state  0
# training accuracy is  84.66295609152752  for random state  1
# testing accuracy is  83.7037037037037  for random state  1
# training accuracy is  84.7247990105133  for random state  2
# testing accuracy is  85.74074074074073  for random state  2
# training accuracy is  84.4155844155844  for random state  3
# testing accuracy is  82.77777777777777  for random state  3
# training accuracy is  85.03401360544217  for random state  4
# testing accuracy is  83.14814814814815  for random state  4
# training accuracy is  84.7247990105133  for random state  5
# testing accuracy is  83.51851851851852  for random state  5
# training accuracy is  85.03401360544217  for random state  6
# testing accuracy is  83.88888888888889  for random state  6
# training accuracy is  85.28138528138528  for random state  7
# testing accuracy is  82.5925925925926  for random state  7
# ...

# %%
#initiating train test split thereafter model training
x_train,x_test,y_train,y_test=train_test_split(princi_comp,y_new,test_size=0.25,random_state=1)

def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print('-----Training score-----')
        print(f'Accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%')
    elif train==False:
        pred=clf.predict(x_test)
        print('-----Testing score-----')
        print(f'Accuracy score:{accuracy_score(y_test,pred)*100:.2f}%')
        print('classification report \n',classification_report (y_test,pred))
        print('confusion matrix ',confusion_matrix(y_test,pred))
        print('F1 Score ',f1_score(y_test,pred,average='micro'))

# %%
#training the model
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#passing the function
metric_score(lr,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(lr,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:84.66%
# -----Testing score-----
# Accuracy score:83.70%
# classification report
#                precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       303
#            1       0.85      0.77      0.81       237
#
#     accuracy                           0.84       540
#    macro avg       0.84      0.83      0.83       540
# weighted avg       0.84      0.84      0.84       540
#
# confusion matrix  [[270  33]
#  [ 55 182]]
# F1 Score  0.837037037037037

# %%
# using cross validation score to check if model is overfitted

#uploading cross validation library
from sklearn.model_selection import cross_val_score

# %%
#finding best value for cv in provided range
for i in range(2,12):
    cv_score=cross_val_score(lr,princi_comp,y_new,cv=i)
    cv=cv_score.mean()
    print('At cv:-',i)
    print('cross validation score:- ',cv*100)
# Out:
# At cv:- 2
# cross validation score:-  81.92066109449931
# At cv:- 3
# cross validation score:-  81.17756142790911
# At cv:- 4
# cross validation score:-  82.11047550333265
# At cv:- 5
# cross validation score:-  82.61858726475897
# At cv:- 6
# cross validation score:-  83.03621169916435
# At cv:- 7
# cross validation score:-  82.99109582049942
# At cv:- 8
# cross validation score:-  83.22094864381108
# At cv:- 9
# cross validation score:-  83.08228730822873
# At cv:- 10
# cross validation score:-  83.87058570198104
# At cv:- 11
# cross validation score:-  83.63862388517937

# %%
#cross validation score
print('Cross Validation Score for Logistic regression model :- ',((cross_val_score(lr,princi_comp,y_new,cv=10).mean())*100))
# Out:
# Cross Validation Score for Logistic regression model :-  83.87058570198104

# %% [markdown]
# # plotting ROC curve

# %%
#importing ROC curve library

from sklearn.metrics import roc_curve,auc

# %%
pred=lr.predict(x_test)
fpr,tpr,threshold=roc_curve(y_test,pred)
print('fpr',fpr)
print('tpr',tpr)
print('threshold',threshold)
# Out:
# fpr [0.         0.10891089 1.        ]
# tpr [0.         0.76793249 1.        ]
# threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='darkorange',label='ROC curve')
plt.plot([0,1],[0,1],color='green',linestyle='--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#passing the function
metric_score(rf,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(rf,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:100.00%
# -----Testing score-----
# Accuracy score:87.22%
# classification report
#                precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       303
#            1       0.92      0.77      0.84       237
#
#     accuracy                           0.87       540
#    macro avg       0.88      0.86      0.87       540
# weighted avg       0.88      0.87      0.87       540
#
# confusion matrix  [[288  15]
#  [ 54 183]]
# F1 Score  0.8722222222222223

# %%
#cross validation score
print('Cross Validation Score for random forest model :- ',((cross_val_score(rf,princi_comp,y_new,cv=10).mean())*100))
# Out:
# Cross Validation Score for random forest model :-  86.93303186907839

# %% [markdown]
# # Plotting ROC curve

# %%
pred=rf.predict(x_test)
fpr,tpr,threshold=roc_curve(y_test,pred)
print('fpr',fpr)
print('tpr',tpr)
print('threshold',threshold)
# Out:
# fpr [0.         0.04950495 1.        ]
# tpr [0.        0.7721519 1.       ]
# threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='darkorange',label='ROC curve')
plt.plot([0,1],[0,1],color='green',linestyle='--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#passing the function
metric_score(dt,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(dt,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:100.00%
# -----Testing score-----
# Accuracy score:74.81%
# classification report
#                precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78       303
#            1       0.72      0.69      0.71       237
#
#     accuracy                           0.75       540
#    macro avg       0.74      0.74      0.74       540
# weighted avg       0.75      0.75      0.75       540
#
# confusion matrix  [[240  63]
#  [ 73 164]]
# F1 Score  0.7481481481481481

# %%
#cross validation score
print('Cross Validation Score for Decision Tree model :- ',((cross_val_score(dt,princi_comp,y_new,cv=10).mean())*100))
# Out:
# Cross Validation Score for Decision Tree model :-  78.72459086993972

# %% [markdown]
# # plotting ROC curve

# %%
pred=dt.predict(x_test)
fpr,tpr,threshold=roc_curve(y_test,pred)
print('fpr',fpr)
print('tpr',tpr)
print('threshold',threshold)
# Out:
# fpr [0.         0.20792079 1.        ]
# tpr [0.         0.69198312 1.        ]
# threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='darkorange',label='ROC curve')
plt.plot([0,1],[0,1],color='green',linestyle='--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbdt=GradientBoostingClassifier()

# %%
gbdt.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
#passing the function
metric_score(gbdt,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(gbdt,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:94.93%
# -----Testing score-----
# Accuracy score:84.63%
# classification report
#                precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       303
#            1       0.88      0.76      0.81       237
#
#     accuracy                           0.85       540
#    macro avg       0.85      0.84      0.84       540
# weighted avg       0.85      0.85      0.84       540
#
# confusion matrix  [[278  25]
#  [ 58 179]]
# F1 Score  0.8462962962962963

# %%
#cross validation score
print('Cross Validation Score for Gradient Boosting model :- ',((cross_val_score(gbdt,princi_comp,y_new,cv=10).mean())*100))
# Out:
# Cross Validation Score for Gradient Boosting model :-  84.52110249784668

# %% [markdown]
# # plotting ROC curve

# %%
pred=gbdt.predict(x_test)
fpr,tpr,threshold=roc_curve(y_test,pred)
print('fpr',fpr)
print('tpr',tpr)
print('threshold',threshold)
# Out:
# fpr [0.         0.08250825 1.        ]
# tpr [0.         0.75527426 1.        ]
# threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='darkorange',label='ROC curve')
plt.plot([0,1],[0,1],color='green',linestyle='--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Dataframe showing training, testing, F1 score and Cross validation scores with respect to different models

# %%
column=pd.DataFrame({'Model':['Logistic Regression','Random Forests','Decision Trees','Gradient Boosted Tees'],
                    'Training scores':[84.66,100,100,94.93],
                    'Testing scores':[83.70,86.67,74.81,84.63],
                    'Cross validation score':[83.87,86.88,78.72,84.52],
                    'F1 score':[83.7,86.6,74.81,84.6]})
column
# Out:
#                    Model  Training scores  Testing scores  \
# 0    Logistic Regression            84.66           83.70
# 1         Random Forests           100.00           86.67
# 2         Decision Trees           100.00           74.81
# 3  Gradient Boosted Tees            94.93           84.63
#
#    Cross validation score  F1 score
# 0                   83.87     83.70
# 1                   86.88     86.60
# 2                   78.72     74.81
# 3                   84.52     84.60

# %% [markdown]
# **Looking at the dataframe I can say that Random Forest is the best model as it has seen 100% of data, it has the best training score compared to other models and also its CV and F1 score are same as training accuracy.**

# %% [markdown]
# # Hyperparameter tuning on Random Forest Classifier Model

# %%
#importing library for for grid search CV

from sklearn.model_selection import GridSearchCV

# %%
grid_param=[{'n_estimators':[100,200,],
           'max_depth':[2,3,4,5,],
           'criterion':['gini','entropy','log_loss'],
            'max_features':["sqrt", "log2", None]}]

# %%
#saving model in variable
grid=GridSearchCV(RandomForestClassifier(),param_grid=grid_param)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid=[{'criterion': ['gini', 'entropy', 'log_loss'],
#                           'max_depth': [2, 3, 4, 5],
#                           'max_features': ['sqrt', 'log2', None],
#                           'n_estimators': [100, 200]}])

# %%
#best parameters for tuning
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'n_estimators': 100}

# %%
#using best parameters to train 
rf1=RandomForestClassifier(n_estimators=100,
                           max_depth=5,
                           criterion='gini',
                           max_features='sqrt')

# %%
rf1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
#passing the function
metric_score(rf1,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(rf1,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:89.92%
# -----Testing score-----
# Accuracy score:82.41%
# classification report
#                precision    recall  f1-score   support
#
#            0       0.80      0.92      0.85       303
#            1       0.88      0.70      0.78       237
#
#     accuracy                           0.82       540
#    macro avg       0.84      0.81      0.82       540
# weighted avg       0.83      0.82      0.82       540
#
# confusion matrix  [[280  23]
#  [ 72 165]]
# F1 Score  0.8240740740740741

# %%
#cross validation score
print('Cross Validation Score for Gradient Boosting model :- ',((cross_val_score(rf1,princi_comp,y_new,cv=10).mean())*100))
# Out:
# Cross Validation Score for Gradient Boosting model :-  84.01227390180878

# %% [markdown]
# # plotting ROC curve for tuned model

# %%
pred=rf1.predict(x_test)
fpr,tpr,threshold=roc_curve(y_test,pred)
print('fpr',fpr)
print('tpr',tpr)
print('threshold',threshold)
# Out:
# fpr [0.         0.07590759 1.        ]
# tpr [0.         0.69620253 1.        ]
# threshold [2 1 0]

# %%
plt.plot(fpr,tpr,color='darkorange',label='ROC curve')
plt.plot([0,1],[0,1],color='green',linestyle='--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Receiver Operating Curve')
plt.legend()
plt.show()

# %% [markdown]
# **The tuned model has low training and testing accuracy then the original model, hence the original random forest classifier model will be saved.**

# %% [markdown]
# # Saving the model

# %%
import pickle

# %%
pickle.dump(rf,open('HR_analysis_rf','wb'))
