# %% [markdown]
# # Zomato Restaurant Project
#
# Problem Statement:
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
# - This problem statement contains two datasets- Zomato.csv and country_code.csv.
# - Country_code.csv contains two variables:
# -  Country code
# -  Country name
# - The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
# -  Restaurant Id: Unique id of every restaurant across various cities of the world
# -  Restaurant Name: Name of the restaurant
# -  Country Code: Country in which restaurant is located
# -  City: City in which restaurant is located
# - Address: Address of the restaurant
# - Locality: Location in the city
# - Locality Verbose: Detailed description of the locality
# - Longitude: Longitude coordinate of the restaurant&#39;s location
# - Latitude: Latitude coordinate of the restaurant&#39;s location
# - Cuisines: Cuisines offered by the restaurant
# - Average Cost for two: Cost for two people in different currencies ��
# - Currency: Currency of the country
# - Has Table booking: yes/no
# - Has Online delivery: yes/ no
# - Is delivering: yes/ no
# - Switch to order menu: yes/no
# - Price range: range of price of food
# - Aggregate Rating: Average rating out of 5
# - Rating color: depending upon the average rating color
# - Rating text: text on the basis of rating of rating
# - Votes: Number of ratings casted by people
#
# - Problem statement : In this dataset predict 2 things –
#  1) Average Cost for two
#  2) Price range

# %%
import pandas as pd
import numpy as np

#importing visualization libraries

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#importing warnings library

import warnings
warnings.filterwarnings('ignore')

# %%
# uploading datasets

df1=pd.read_excel('Country-Code.xlsx')

# %%
# uploading datasets

df2=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv',encoding="latin-1")

# %%
#merging 2 dataframes into one

data=pd.merge(df1,df2)

# %%
#printing dataframe

data
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
#printing column names

data.columns
# Out:
# Index(['Country Code', 'Country', 'Restaurant ID', 'Restaurant Name', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#checking for null values in dataset

data.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# checking for duplicate values in dataset

data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There are no duplicate data present in dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data['Country Code'].unique()
# Out:
# array([  1,  14,  30,  37,  94, 148, 162, 166, 184, 189, 191, 208, 214,
#        215, 216], dtype=int64)

# %%
len(data['Country Code'].unique())
# Out:
# 15

# %%
data['Country'].unique()
# Out:
# array(['India', 'Australia', 'Brazil', 'Canada', 'Indonesia',
#        'New Zealand', 'Phillipines', 'Qatar', 'Singapore', 'South Africa',
#        'Sri Lanka', 'Turkey', 'UAE', 'United Kingdom', 'United States'],
#       dtype=object)

# %%
len(data['Country'].unique())
# Out:
# 15

# %% [markdown]
# - It can be seen that Country code and country have same lengths, this means that  the column data is unique and is identical but with different data points. For ex. India had country code of 1, simiarly USA has country code of 216.
# - **Hence 1 column can be dropped as both the columns consists of same understandable data.**

# %%
data['Restaurant ID'].unique()
# Out:
# array([ 3400025,  3400341,  3400005, ..., 17697332, 17694056, 17559793],
#       dtype=int64)

# %%
len(data['Restaurant ID'].unique())
# Out:
# 9551

# %% [markdown]
# - **This is the unique ID provided to retaurants from all over the world by Zomato for their order processing. This column can be dropped as it will not have much importance in model building.**

# %%
data['Restaurant Name'].unique()
# Out:
# array(['Jahanpanah', 'Rangrezz Restaurant', 'Time2Eat - Mama Chicken',
#        ..., 'Tokyo Japanese Steak House',
#        "Theo Yianni's Authentic Greek Restaurant",
#        "Fishpatrick's Crabby Cafe"], dtype=object)

# %%
data['Restaurant Name'].value_counts()
# Out:
# Cafe Coffee Day                       83
# Domino's Pizza                        79
# Subway                                63
# Green Chick Chop                      51
# McDonald's                            48
#                                       ..
# Chor Bizarre - Hotel Broadway          1
# Thugs - Hotel Broadway                 1
# The Kylin Experience - Holiday Inn     1
# Cafe on 3 - Holiday Inn                1
# Fishpatrick's Crabby Cafe              1
# Name: Restaurant Name, Length: 7446, dtype: int64

# %% [markdown]
# - **Restaurant Name column contains names of all the retaurants that are present in this dataset. Its count suggests the number of franchises that are under Zomato panel. For ex, Cafe Coffee Day has total of 83 franchises registered under Zomato.**

# %%
data['City'].value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Vineland Station       1
# Yorkton                1
# Bandung                1
# Quezon City            1
# Winchester Bay         1
# Name: City, Length: 141, dtype: int64

# %%
plt.figure(figsize=(50,7))
sns.countplot(data['City'])
plt.xticks(rotation=90)
plt.title('Frequnecy of restaurants registered under Zomato')
plt.show()

# %% [markdown]
# - it can be seen from the plot that most restaurants registered under zomato are from New Delhi, followed by Gurgaon, Noida and Faridabad.

# %%
data['Address'].value_counts()
# Out:
# Sector 41, Noida                                                                      11
# Dilli Haat, INA, New Delhi                                                            11
# Greater Kailash (GK) 1, New Delhi                                                     10
# The Imperial, Janpath, New Delhi                                                       9
# The Lalit, Barakhamba Avenue, Barakhamba Road, New Delhi                               8
#                                                                                       ..
# G-4, Local Shopping Complex, Gujranwala Town, New Delhi                                1
# State Bank Colony, Near Nanak Piau Gurudwara, GTK Road, Gujranwala Town, New Delhi     1
# Shop 6 & 7, DDA Market, Near Pentamed Hospital, Gujranwala Town, New Delhi             1
# A-199, Gujranwala Town, New Delhi                                                      1
# ...

# %%
data['Locality'].value_counts()
# Out:
# Connaught Place    122
# Rajouri Garden      99
# Shahdara            87
# Defence Colony      86
# Pitampura           85
#                   ...
# Waltair Uplands      1
# Armidale             1
# Balingup             1
# Beechworth           1
# Winchester Bay       1
# Name: Locality, Length: 1208, dtype: int64

# %% [markdown]
# - **Above columns which are 'Address' and 'Locality' give the complete address of the restaurant, while locality give the landmark where the restaurant is located.**

# %%
data['Locality Verbose'].value_counts()
# Out:
# Connaught Place, New Delhi             122
# Rajouri Garden, New Delhi               99
# Shahdara, New Delhi                     87
# Defence Colony, New Delhi               86
# Pitampura, New Delhi                    85
#                                       ...
# Hotel Maurya, Lodipur, Patna             1
# Maurya Lok, Fraser Road Area, Patna      1
# Patliputra Colony, Patna                 1
# Heritage Town, Puducherry                1
# Winchester Bay, Winchester Bay           1
# Name: Locality Verbose, Length: 1265, dtype: int64

# %% [markdown]
# - **This column provides with the normal go-to address that people provided by referring landmark. There are total of 1265 addresses of different restaurants.**

# %% [markdown]
# **Latitude and Longitude provides the pinpoint location of the restaurants that are present in this dataset.**

# %%
plt.figure(figsize=(50,7))
sns.countplot(data['Average Cost for two'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - **In most of the restaurants the average cost for 2 ranges from as low as 1-7 USD and maximum upto  80000 USD.**
# - **Most people paid 300 and 500 as the average cost for 2 depending upon type of restaurant.**

# %%
plt.figure(figsize=(50,7))
sns.countplot(data['Currency'])
plt.xticks(rotation=90)
plt.title('Currency used by  restaurants registered under Zomato')
plt.show()

# %% [markdown]
# - **Since most of the restaurants are Indian in nature they use Indian currency i.e. Rupee as seen in plot above.**

# %%
sns.countplot(data['Has Table booking'])
plt.xticks(rotation=90)
plt.title('Frequnecy of restaurants providing Table booking under Zomato')
plt.show()

# %% [markdown]
# - **Since Zomato is basically food delivery app, less number of restaurants provide table booking via Zomato or they might not have that service yet.**
# - **Only roughly 1000 nos of restaurants has table booking.**

# %%
sns.countplot(data['Has Online delivery'])
plt.xticks(rotation=90)
plt.title('Frequnecy of restaurants having online delivery under Zomato')
plt.show()

# %% [markdown]
# - **There are more number of restaurants who does not have their own online food delivery. These restaurants rely on either Zomato to deliver their food or by people to pick their order.**
# - **Approx. >2000 restaurants have their own online delivery.**

# %%
sns.countplot(data['Is delivering now'])
plt.xticks(rotation=90)
plt.title('Frequnecy of restaurants delivering now under Zomato')
plt.show()

# %% [markdown]
# - **Most restaurants are not delivering now under Zomato.**

# %%
sns.countplot(data['Switch to order menu'])
plt.xticks(rotation=90)
plt.title('Frequnecy of restaurants switching to order menu in  Zomato')
plt.show()

# %% [markdown]
# - **All the restaurants dont switch to order menu under Zomato.**
# - **Since this column has only 1 output, this column is not useful in model building, hence it will dropped in future.**

# %%
sns.countplot(data['Price range'])
plt.xticks(rotation=90)
plt.title('Frequnecy of price range of restaurants under Zomato')
plt.show()

# %% [markdown]
# - **More than 4000 restaurants fall in the price range of 1. As the category of price range increases, the number of restaurants falling in that  categpry decreses.**

# %%
sns.countplot(data['Aggregate rating'])
plt.xticks(rotation=90)
plt.title('Frequnecy of restaurants Aggregate rating under Zomato')
plt.show()

# %% [markdown]
# - **Many less retaurants received 5 star rating with too many restaurants getting 0-1.5 aggregate rating.**
# - **The average rating receibed to restaurants should be around 2.8-4.1.**

# %%
sns.countplot(data['Rating color'])
plt.xticks(rotation=90)
plt.title('Frequnecy of rating color for restaurants registered under Zomato')
plt.show()

# %%
data['Rating color'].value_counts()
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %% [markdown]
# - **Most of the restaurants received  Orange as rating color followed by white and yellow.**
# - **The least rated color is Red.**

# %%
data['Rating text'].value_counts()
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
sns.countplot(data['Rating text'])
plt.xticks(rotation=90)
plt.title('Frequnecy of restaurants ratings under Zomato')
plt.show()

# %% [markdown]
# - **Most of the restaurants have scored Average rating.**
# - **Very less restaurants have a average rating of Poor while almost >250 restaurants have received excellent rating.**

# %%
data['Votes'].value_counts()
# Out:
# 0       1094
# 1        483
# 2        327
# 3        244
# 4        207
#         ...
# 1801       1
# 1333       1
# 1863       1
# 1134       1
# 575        1
# Name: Votes, Length: 1012, dtype: int64

# %% [markdown]
# - **This column consists of Votes given to different restaurants.**

# %%
# Dropping columns that are not related to label (Average price for 2 and Price range) and not useful for model building


data.drop(['Country Code','Restaurant ID','Address','Locality','Switch to order menu'],axis=1,inplace=True)

# %% [markdown]
# - **Dropped Address and Locality columns as City gives the city name where restaurant is located with latitude and longutude providing pinpoint locations plus Location Verbose providing landmark for that restaurant.**
# - **Explanation why I dropped other columns provided when I described those columns with value counts above**

# %%
data.head()
# Out:
#   Country                        Restaurant Name  City   Locality Verbose  \
# 0   India                             Jahanpanah  Agra   Agra Cantt, Agra
# 1   India                    Rangrezz Restaurant  Agra   Agra Cantt, Agra
# 2   India                Time2Eat - Mama Chicken  Agra   Agra Cantt, Agra
# 3   India  Chokho Jeeman Marwari Jain Bhojanalya  Agra  Civil Lines, Agra
# 4   India                         Pinch Of Spice  Agra  Civil Lines, Agra
#
#    Longitude   Latitude                        Cuisines  Average Cost for two  \
# 0  78.011544  27.161661           North Indian, Mughlai                   850
# 1   0.000000   0.000000           North Indian, Mughlai                   700
# 2  78.011608  27.160832                    North Indian                   500
# 3  77.998092  27.195928                      Rajasthani                   400
# 4  78.007553  27.201725  North Indian, Chinese, Mughlai                  1000
#
# ...

# %%
data.shape
# Out:
# (9551, 17)

# %%
sns.barplot(x='Country',y='Average Cost for two',data=data,hue='Currency')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.02, 1), loc=2)
plt.show()

# %% [markdown]
# - Average cost for 2 is very much high in Indonesia compared to other countries when the price is charged in Indinesian Rupiah.

# %%
plt.figure(figsize=(50,7))
sns.barplot(x=data['City'],y='Average Cost for two',data=data,hue='Currency')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.02, 1), loc=2)
plt.show()

# %% [markdown]
# - As mentioned above Average cost for two is highest in Bangdung,Bogor,Jakarta,Tangerang cities. This belongs to Indonesia.

# %%
data.sort_values(by='Average Cost for two',ascending=False)[:50][['Cuisines','Average Cost for two','Country']]
# Out:
#                                                Cuisines  Average Cost for two  \
# 8748                         Asian, Indonesian, Western                800000
# 8747                               Italian, Continental                800000
# 8751                                    Sushi, Japanese                500000
# 8753                                           Japanese                450000
# 8758                                    French, Western                350000
# 8759                                         Indonesian                300000
# 8752                                      Cafe, Western                300000
# 8742                              Peranakan, Indonesian                250000
# 8749                               Western, Asian, Cafe                250000
# 8760                                  Sunda, Indonesian                200000
# 8743                                  Sunda, Indonesian                200000
# ...

# %%
data.sort_values(by='Average Cost for two',ascending=False)[:50][['Cuisines','Average Cost for two','Country']].plot(kind='bar')
plt.show()

# %% [markdown]
# - The above dataset and plot shows the top 50 cuisines wherein the average price for 2 in deccending order.

# %%
sns.barplot(x='Has Table booking',y='Average Cost for two',data=data,hue='Price range')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - From above plot it can be seen that Average cost for 2 is lower if the restaurant has table booking and falls within the price range 1.
# - Price range is very high for restaurants that does not have Table booking.

# %%
sns.barplot(x='Has Online delivery',y='Average Cost for two',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - It can be seen from the plot that Average cost for 2 is high if the restaurant does not have online delivery and vice versa.

# %%
sns.barplot(x='Is delivering now',y='Average Cost for two',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Average price is higher if restaurant is not delivering now and vice versa.

# %%
sns.barplot(x='Price range',y='Average Cost for two',data=data)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - The above plot suggests that as the price range increase the average cost for 2 increases.

# %%
sns.barplot(x='Aggregate rating',y='Average Cost for two',data=data)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - In most of the restaurants, as the aggregate rating increases the average cost for 2 increases the.This is not seen in all the restaurants as some restaurants with 4.8 rating has lower cost then 3.7 rated restaurant

# %%
sns.barplot(x='Rating color',y='Average Cost for two',data=data)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - The above plot suggest that Dark green colored rated restaurant has the highest cost for on an average 2 people.
# - While the restaurants marked in white has least average cost for 2.

# %%
sns.barplot(x='Rating text',y='Average Cost for two',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Excellent rated restaurants has highest average cost for 2 people and poor rated restaurants has lower cost for 2.

# %%
sns.barplot(x='Country',y='Price range',data=data,hue='Currency')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.02, 1), loc=2)
plt.show()

# %% [markdown]
# - Compared to other countries, India has the cheapest price range restaurants on Zomato. The highest price range fir restaurants is seen in Qatar and Singapore.

# %%
plt.figure(figsize=(50,7))
sns.barplot(x='City',y='Price range',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The above plot shows the city wise price range for restaurants on Zomato.

# %%
data.sort_values(by='Price range',ascending=False)[:50][['Cuisines','Price range','Country','Restaurant Name']]
# Out:
#                                                Cuisines  Price range  \
# 3382                 Finger Food, North Indian, Chinese            4
# 8697                                     Desserts, Cafe            4
# 9023                                  Pakistani, Indian            4
# 8702                                Brazilian, Bar Food            4
# 9021                                           Lebanese            4
# 8704                                Brazilian, Bar Food            4
# 9019             Indian, Mughlai, South Indian, Biryani            4
# 2058                                   Japanese, Korean            4
# 518                                           Fast Food            4
# 519                                         Finger Food            4
# 520   Continental, North Indian, Italian, Seafood, Goan            4
# 8705                                          Brazilian            4
# 522   North Indian, Chinese, Continental, Goan, Seafood            4
# ...

# %% [markdown]
# The above dataset shows the top 50 Cuisines with restaurant names sorted price rangewise for different countries.

# %%
sns.barplot(x='Has Table booking',y='Price range',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The restaurants with table booking has higher price range then non table booking ones.

# %%
sns.barplot(x='Has Online delivery',y='Price range',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The restaurants that has online delivery has higher price range and vice versa.

# %%
sns.barplot(x='Aggregate rating',y='Price range',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The restaurants having higher rating has higher price range. It is also seen that restaurants with price range of 3 has rating of only 1.8.

# %%
sns.barplot(x='Rating color',y='Price range',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The above plot suggests that dark green rated restaurants have high price range then others.

# %%
sns.barplot(x='Rating text',y='Price range',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - The above plot suggests that Excellent rated restaurants have higher price range then Very good ones.
# - Price range is lowest for non rated restaurants.

# %% [markdown]
# # Label Encoding

# %%
data.columns
# Out:
# Index(['Country', 'Restaurant Name', 'City', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#importing library for label encoder

from sklearn.preprocessing import LabelEncoder

label_enc=LabelEncoder()

# %%
#transforming the data
df1=label_enc.fit_transform(data['Country'])
df2=label_enc.fit_transform(data['Restaurant Name'])
df3=label_enc.fit_transform(data['City'])
df4=label_enc.fit_transform(data['Locality Verbose'])
df5=label_enc.fit_transform(data['Cuisines'])
df6=label_enc.fit_transform(data['Currency'])
df7=label_enc.fit_transform(data['Has Table booking'])
df8=label_enc.fit_transform(data['Has Online delivery'])
df9=label_enc.fit_transform(data['Is delivering now'])
df11=label_enc.fit_transform(data['Rating color'])
df12=label_enc.fit_transform(data['Rating text'])

# %%
data['Country']=df1
data['Restaurant Name']=df2
data['City']=df3
data['Locality Verbose']=df4
data['Cuisines']=df5
data['Currency']=df6
data['Has Table booking']=df7
data['Has Online delivery']=df8
data['Is delivering now']=df9
data['Rating color']=df11
data['Rating text']=df12

# %%
data.head()
# Out:
#    Country  Restaurant Name  City  Locality Verbose  Longitude   Latitude  \
# 0        3             3201     1                17  78.011544  27.161661
# 1        3             5261     1                17   0.000000   0.000000
# 2        3             6919     1                17  78.011608  27.160832
# 3        3             1637     1               205  77.998092  27.195928
# 4        3             4922     1               205  78.007553  27.201725
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0      1514                   850         4                  0
# 1      1514                   700         4                  0
# 2      1306                   500         4                  0
# 3      1645                   400         4                  0
# 4      1373                  1000         4                  0
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               9551 non-null   int32
#  1   Restaurant Name       9551 non-null   int32
#  2   City                  9551 non-null   int32
#  3   Locality Verbose      9551 non-null   int32
#  4   Longitude             9551 non-null   float64
#  5   Latitude              9551 non-null   float64
#  6   Cuisines              9551 non-null   int32
#  7   Average Cost for two  9551 non-null   int64
#  8   Currency              9551 non-null   int32
#  9   Has Table booking     9551 non-null   int32
#  10  Has Online delivery   9551 non-null   int32
#  11  Is delivering now     9551 non-null   int32
#  12  Price range           9551 non-null   int64
#  13  Aggregate rating      9551 non-null   float64
#  14  Rating color          9551 non-null   int32
# ...

# %%
data.describe()
# Out:
#            Country  Restaurant Name         City  Locality Verbose  \
# count  9551.000000      9551.000000  9551.000000       9551.000000
# mean      3.736781      3653.204586    78.301434        677.304994
# std       2.651963      2142.917876    23.198915        331.727449
# min       0.000000         0.000000     0.000000          0.000000
# 25%       3.000000      1777.500000    76.000000        387.000000
# 50%       3.000000      3595.000000    88.000000        707.000000
# 75%       3.000000      5485.500000    88.000000        953.000000
# max      14.000000      7445.000000   140.000000       1264.000000
#
#          Longitude     Latitude    Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.00000           9551.000000
# mean     64.126574    25.854381   989.95079           1199.210763
# std      41.467058    11.007935   514.72354          16121.183073
# min    -157.948486   -41.330428     0.00000              0.000000
# ...

# %% [markdown]
# - Looking at the table above it can be seen that there is presence of outliers in some columns for ex, Average cost for 2 column.
# - I need to check these dataset for skewness too.

# %% [markdown]
# **Plotting the correlation matrix to check for correlation**

# %%
#plotting heatmap

plt.figure(figsize=(30,30))
corr=data.corr()
sns.heatmap(corr,annot=True)
plt.title('Correlation matrix')
plt.show()

# %% [markdown]
# - I take 75% as the minimum value for multicollinearity problem.
# - In this case Longitude is related to Country by 77%.

# %%
sns.scatterplot(x='Longitude',y='Country',data=data)
plt.title('relation between Longitude and Country')
plt.show()

# %% [markdown]
# - There is no relationship seen in this plot.

# %%
#plotting a coorelation plot that will show relation of features with label(Average Cost for tw)

plt.figure(figsize=(15,5))
data.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Average Cost for two')
plt.title('correlation')
plt.show()

# %% [markdown]
# - Highest positive relation is seen with Price range and highest negative relation is seen with Latitude.
# - The least related is 'Is delivering now'.

# %%
#plotting a coorelation plot that will show relation of features with label(Price range)

plt.figure(figsize=(15,5))
data.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Price range')
plt.title('correlation')
plt.show()

# %% [markdown]
# - Highest  positively related to label(price range) is Has table booking column while highest negatively related column is Latitude.
# - The least related to label Price range is Cruises.

# %% [markdown]
# # Since there are 2 labels based on which I need to perform Machine learning model, Hence I'm saving this dataset in seperate variable (df) to be used for other model.

# %%
#making dataframe with same columns and values as original dataframe with name as df 

df=pd.DataFrame(data,columns=['Country', 'Restaurant Name', 'City', 'Locality Verbose', 'Longitude',
       'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
       'Has Table booking', 'Has Online delivery', 'Is delivering now',
       'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
       'Votes'])

df.head() #printing dataframe
# Out:
#    Country  Restaurant Name  City  Locality Verbose  Longitude   Latitude  \
# 0        3             3201     1                17  78.011544  27.161661
# 1        3             5261     1                17   0.000000   0.000000
# 2        3             6919     1                17  78.011608  27.160832
# 3        3             1637     1               205  77.998092  27.195928
# 4        3             4922     1               205  78.007553  27.201725
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0      1514                   850         4                  0
# 1      1514                   700         4                  0
# 2      1306                   500         4                  0
# 3      1645                   400         4                  0
# 4      1373                  1000         4                  0
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# ...

# %%
df.shape
# Out:
# (9551, 17)

# %% [markdown]
# # Moving forward with removing outliers,skewness and feature selection and thereby making Machine Learning model with label as ' Average Cost for two'.

# %%
# this dataset will be used for this label

data
# Out:
#       Country  Restaurant Name  City  Locality Verbose   Longitude   Latitude  \
# 0           3             3201     1                17   78.011544  27.161661
# 1           3             5261     1                17    0.000000   0.000000
# 2           3             6919     1                17   78.011608  27.160832
# 3           3             1637     1               205   77.998092  27.195928
# 4           3             4922     1               205   78.007553  27.201725
# ...       ...              ...   ...               ...         ...        ...
# 9546       14             6794   135              1231  -92.335523  42.498400
# 9547       14             6839   135              1231  -92.335769  42.497919
# 9548       14             6945   135              1231  -92.323400  42.465580
# 9549       14             6883   136              1233  -80.529488  40.396043
# 9550       14             2342   138              1243 -124.175346  43.678998
#
# ...

# %% [markdown]
# # Checking for outliers in dataset

# %%
features=['Longitude','Latitude','Aggregate rating','Votes']

# %%
plt.figure(figsize=(15,15))
plotnumber=1

for column in features:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# - It can be seen from the plots that all these columns has outliers in it.

# %% [markdown]
# # Removal of outliers using z-score method

# %%
#importing z score library

from scipy.stats import zscore

# %%
z_score=zscore(data[['Longitude','Latitude','Aggregate rating','Votes']])

# %%
abs_z_score=np.abs(z_score)

# %%
filtering_entry=(abs_z_score<3).all(axis=1)

# %%
data=data[filtering_entry]

# %%
data.shape
# Out:
# (8772, 17)

# %% [markdown]
# # Data loss after removing outliers

# %%
# data loss percentage 
data_loss=((9551-8772)/8772)*100
print(f'data loss in percent after removing outliers is: {data_loss}%')
# Out:
# data loss in percent after removing outliers is: 8.880528955768353%

# %% [markdown]
# # Checking for skewness in dataset

# %%
data[features].skew()
# Out:
# Longitude          -3.154060
# Latitude           -2.254203
# Aggregate rating   -0.888635
# Votes               3.532071
# dtype: float64

# %% [markdown]
# - It can be seen that all the continuous data columns have skewness present.
#
# **Confirming that with distplots below.**

# %%
plt.figure(figsize=(15,15))
plotnumber=1

for column in features:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# **skewness can be seen in above plots for all columns, hence removing skewness using power transformer method.**
#
# # Hence removing skewness using Power Transformer

# %%
#importing library
from sklearn.preprocessing import PowerTransformer

scaler=PowerTransformer(method='yeo-johnson') #using yeo-johnson method to transform

# %%
#transforming the data
data[features]=scaler.fit_transform(data[features])

# %%
#printing features to check for skewness
data[features].skew()
# Out:
# Longitude          -0.973902
# Latitude            0.343832
# Aggregate rating   -0.619464
# Votes              -0.012469
# dtype: float64

# %% [markdown]
# # Using Select KBest feature selection method to find best features to build a model.

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
X=data.drop(['Average Cost for two'],axis=1)
Y=data['Average Cost for two']

# %%
best_features=SelectKBest(score_func=f_classif,k=14)
fit=best_features.fit(X,Y)
df_scores=pd.DataFrame(fit.scores_)
df_columns=pd.DataFrame(X.columns)
feature_score=pd.concat([df_columns,df_scores],axis=1)
feature_score.columns=['Feature Name','Score']
print(feature_score.nlargest(14,'Score'))
# Out:
#            Feature Name       Score
# 11          Price range  702.988827
# 0               Country  161.276116
# 8     Has Table booking   76.954894
# 15                Votes   33.957618
# 7              Currency   32.421287
# 5              Latitude   24.951927
# 12     Aggregate rating   20.667526
# 4             Longitude   11.556599
# 9   Has Online delivery    9.680622
# 14          Rating text    4.872016
# 2                  City    4.404113
# 13         Rating color    3.362687
# 3      Locality Verbose    2.866779
# 6              Cuisines    2.504881

# %%
x=data[['Country','City', 'Locality Verbose','Latitude', 'Cuisines', 'Currency','Has Table booking', 'Has Online delivery',
       'Price range', 'Aggregate rating', 'Rating color', 'Rating text','Votes']]

# %% [markdown]
# # Scaling the data

# %%
#importing data standardizing library

from sklearn.preprocessing import StandardScaler

# %%
#Standardizing data
scaler=StandardScaler()

# %%
#scaling features

x_scaled=scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-0.16603274, -3.80904284, -2.07235767, ...,  1.39112894,
#          0.19941974,  0.94391913],
#        [-0.16603274, -3.80904284, -2.07235767, ...,  1.39112894,
#          0.19941974,  0.58572688],
#        [-0.16603274, -3.80904284, -2.07235767, ...,  1.39112894,
#          0.19941974,  0.73288018],
#        ...,
#        [ 7.15643698, -0.24724596,  1.16815012, ..., -1.42988085,
#          2.03436025,  1.85294267],
#        [ 7.15643698, -0.24724596,  1.35622907, ..., -1.42988085,
#          2.03436025,  0.55548701],
#        [ 7.15643698, -0.24724596,  1.35622907, ..., -1.42988085,
#          2.03436025,  0.83477745]])

# %% [markdown]
# # Model Building part

# %%
#importing library for regression model
from sklearn.ensemble import RandomForestRegressor

#importing r2 score
from sklearn.metrics import r2_score

#importing train test split
from sklearn.model_selection import train_test_split

from sklearn import metrics

# %%
rf=RandomForestRegressor()

# %%
#finding best random state for random forest model
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,Y,test_size=0.25,random_state=i)
    rf.fit(x_train,y_train)
    y_pred=rf.predict(x_train)
    pred=rf.predict(x_test)
    print('training score is ',(metrics.r2_score(y_train,y_pred)*100),' for random state ',i)
    print('testing score is ',(metrics.r2_score(y_test,pred)*100),' for random state ',i)
    print('\n')
# Out:
# training score is  91.20306884009665  for random state  0
# testing score is  84.37896035783393  for random state  0
#
#
# training score is  93.82645511161348  for random state  1
# testing score is  60.973653171218054  for random state  1
#
#
# training score is  96.24707437805328  for random state  2
# testing score is  64.35631182096897  for random state  2
#
#
# training score is  94.13443053003499  for random state  3
# testing score is  66.57798879468169  for random state  3
#
#
# training score is  92.41967927186687  for random state  4
# testing score is  19.27972880751766  for random state  4
#
#
# training score is  95.66651827607537  for random state  5
# testing score is  70.57618944196807  for random state  5
#
#
# training score is  96.58718122764837  for random state  6
# testing score is  45.63049254303048  for random state  6
#
#
# training score is  96.5916852466855  for random state  7
# testing score is  -297.3774883312784  for random state  7
#
#
# ...

# %% [markdown]
# # Taking random state as 13 for future machine learning models.

# %%
#making train and test data split

x_train,x_test,y_train,y_test=train_test_split(x_scaled,Y,test_size=0.25,random_state=13)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# since thge model is already trained, below code will help to predict based on train and test data

y_pred=rf.predict(x_train) 

pred=rf.predict(x_test)

#printing r2 score for testing and training models.
#r2 score give value of how good the model has studied and learnt the data

print(f'training R2 score:{r2_score(y_train,y_pred)*100:.2f}%')
print(f'testing R2 score:{r2_score(y_test,pred)*100:.2f}%')
# Out:
# training R2 score:93.29%
# testing R2 score:93.65%

# %% [markdown]
# # finding cross validation score

# %%
#importing library for cross validation score
from sklearn.model_selection import cross_val_score

# %%
#finding best value for cv in provided range
for i in range(2,20):
    cv_score=cross_val_score(rf,x_scaled,Y,cv=i)
    cv=cv_score.mean()
    print('At cv:-',i)
    print('cross validation score:- ',cv*100)
# Out:
# At cv:- 2
# cross validation score:-  -424.28125572010737
# At cv:- 3
# cross validation score:-  -202.42595117364536
# At cv:- 4
# cross validation score:-  -657.795595022101
# At cv:- 5
# cross validation score:-  -1143.3502674645665
# At cv:- 6
# cross validation score:-  62.68626835095995
# At cv:- 7
# cross validation score:-  61.6264610972741
# At cv:- 8
# cross validation score:-  60.181173192164714
# At cv:- 9
# cross validation score:-  62.56234570592838
# At cv:- 10
# cross validation score:-  59.83993134341927
# At cv:- 11
# cross validation score:-  63.78070636876715
# At cv:- 12
# cross validation score:-  58.89232398001414
# At cv:- 13
# cross validation score:-  67.1717681881077
# At cv:- 14
# cross validation score:-  69.19874082818154
# At cv:- 15
# cross validation score:-  47.297899414269054
# At cv:- 16
# cross validation score:-  53.83886141472263
# At cv:- 17
# cross validation score:-  49.51232127954216
# At cv:- 18
# ...

# %%
#cross validation score
print('Cross Validation Score for Random Forest regressor model :- ',((cross_val_score(rf,x_scaled,Y,cv=19).mean())*100))
# Out:
# Cross Validation Score for Random Forest regressor model :-  70.19069599282155

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#finding mean absolute error() for above model(MAE)
print('mean absolute error',mean_absolute_error(y_test,pred))

#finding root mean_squared_error(RMSE)
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absolute error 200.1675558595531
# root mean squared error 1980.8985117022805

# %%
#plotting scatter plot for predicted vs actual

plt.scatter(y_test,pred)
plt.plot(y_test,y_test,color='r')
plt.xlabel('actual average cost for 2')
plt.ylabel('predicted average cost for 2')
plt.title('actual vs model predicted')
plt.show()

# %%
#importing libraries for AdaBoost,Decision Tree and Xgboost regressor

from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
#saving models in variables
ab=AdaBoostRegressor()
dt=DecisionTreeRegressor()
xgb=xgb.XGBRegressor()

# %% [markdown]
# # AdaBoost Regressor

# %%
ab.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
# since thge model is already trained, below code will help to predict based on train and test data

y_pred=ab.predict(x_train) 

pred=ab.predict(x_test)

#printing r2 score for testing and training models.
#r2 score give value of how good the model has studied and learnt the data

print(f'training R2 score:{r2_score(y_train,y_pred)*100:.2f}%')
print(f'testing R2 score:{r2_score(y_test,pred)*100:.2f}%')
# Out:
# training R2 score:97.01%
# testing R2 score:79.51%

# %%
#cross validation score
print('Cross Validation Score for AdaBoost regressor model :- ',((cross_val_score(ab,x_scaled,Y,cv=19).mean())*100))
# Out:
# Cross Validation Score for AdaBoost regressor model :-  -148.68390178420898

# %%
#finding mean absolute error() for above model(MAE)
print('mean absolute error',mean_absolute_error(y_test,pred))

#finding root mean_squared_error(RMSE)
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absolute error 598.1742223210719
# root mean squared error 3774.226971735408

# %%
#plotting scatter plot for predicted vs actual

plt.scatter(y_test,pred)
plt.plot(y_test,y_test,color='r')
plt.xlabel('actual average cost for 2')
plt.ylabel('predicted average cost for 2')
plt.title('actual vs model predicted')
plt.show()

# %% [markdown]
# # Decision Tree Model

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
# since thge model is already trained, below code will help to predict based on train and test data

y_pred=dt.predict(x_train) 

pred=dt.predict(x_test)

#printing r2 score for testing and training models.
#r2 score give value of how good the model has studied and learnt the data

print(f'training R2 score:{r2_score(y_train,y_pred)*100:.2f}%')
print(f'testing R2 score:{r2_score(y_test,pred)*100:.2f}%')
# Out:
# training R2 score:100.00%
# testing R2 score:24.49%

# %%
#cross validation score
print('Cross Validation Score for Decision Tree regressor model :- ',((cross_val_score(dt,x_scaled,Y,cv=19).mean())*100))
# Out:
# Cross Validation Score for Decision Tree regressor model :-  70.48528222549437

# %%
#finding mean absolute error() for above model(MAE)
print('mean absolute error',mean_absolute_error(y_test,pred))

#finding root mean_squared_error(RMSE)
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absolute error 453.1988144094847
# root mean squared error 7245.282490369376

# %%
#plotting scatter plot for predicted vs actual

plt.scatter(y_test,pred)
plt.plot(y_test,y_test,color='r')
plt.xlabel('actual average cost for 2')
plt.ylabel('predicted average cost for 2')
plt.title('actual vs model predicted')
plt.show()

# %% [markdown]
# # XGB

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
# since thge model is already trained, below code will help to predict based on train and test data

y_pred=xgb.predict(x_train) 

pred=xgb.predict(x_test)

#printing r2 score for testing and training models.
#r2 score give value of how good the model has studied and learnt the data

print(f'training R2 score:{r2_score(y_train,y_pred)*100:.2f}%')
print(f'testing R2 score:{r2_score(y_test,pred)*100:.2f}%')
# Out:
# training R2 score:100.00%
# testing R2 score:89.67%

# %%
#cross validation score
print('Cross Validation Score for XGB regressor model :- ',((cross_val_score(xgb,x_scaled,Y,cv=19).mean())*100))
# Out:
# Cross Validation Score for XGB regressor model :-  63.21331522043367

# %%
#finding mean absolute error() for above model(MAE)
print('mean absolute error',mean_absolute_error(y_test,pred))

#finding root mean_squared_error(RMSE)
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absolute error 221.4198976696978
# root mean squared error 2680.053227884753

# %%
#plotting scatter plot for predicted vs actual

plt.scatter(y_test,pred)
plt.plot(y_test,y_test,color='r')
plt.xlabel('actual average cost for 2')
plt.ylabel('predicted average cost for 2')
plt.title('actual vs model predicted')
plt.show()

# %% [markdown]
# # Gradient Boosting Regressor

# %%
gbdt=GradientBoostingRegressor()

# %%
gbdt.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
# since thge model is already trained, below code will help to predict based on train and test data

y_pred=gbdt.predict(x_train) 

pred=gbdt.predict(x_test)

#printing r2 score for testing and training models.
#r2 score give value of how good the model has studied and learnt the data

print(f'training R2 score:{r2_score(y_train,y_pred)*100:.2f}%')
print(f'testing R2 score:{r2_score(y_test,pred)*100:.2f}%')
# Out:
# training R2 score:99.94%
# testing R2 score:75.12%

# %%
#cross validation score
print('Cross Validation Score for Gradient Boosting model :- ',((cross_val_score(gbdt,x_scaled,Y,cv=19).mean())*100))
# Out:
# Cross Validation Score for Gradient Boosting model :-  74.10479704290907

# %%
#finding mean absolute error() for above model(MAE)
print('mean absolute error',mean_absolute_error(y_test,pred))

#finding root mean_squared_error(RMSE)
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absolute error 256.78403695973617
# root mean squared error 4159.0240371156315

# %%
#plotting scatter plot for predicted vs actual

plt.scatter(y_test,pred)
plt.plot(y_test,y_test,color='r')
plt.xlabel('actual average cost for 2')
plt.ylabel('predicted average cost for 2')
plt.title('actual vs model predicted')
plt.show()

# %% [markdown]
# # Dataframe showing training, testing and Cross validation scores with respect to different models

# %%
column=pd.DataFrame({'Model':['Random Forest','AdaBoost','Decision Trees','XGB','Gradient Boosted Tees'],
                    'Training scores':[94.59,97.01,100,100,99.94],
                    'Testing scores':[94.36,79.51,24.49,89.67,75.12],
                    'Cross validation score':[70,-148.68,70.48,63.21,74.10]})
column
# Out:
#                    Model  Training scores  Testing scores  \
# 0          Random Forest            94.59           94.36
# 1               AdaBoost            97.01           79.51
# 2         Decision Trees           100.00           24.49
# 3                    XGB           100.00           89.67
# 4  Gradient Boosted Tees            99.94           75.12
#
#    Cross validation score
# 0                   70.00
# 1                 -148.68
# 2                   70.48
# 3                   63.21
# 4                   74.10

# %% [markdown]
# **Since the Random Forest has better Training and testing score then others, doing hyperparameter tuning on that model.**
# # Hyperparameter tuning for Random Forest Regressor model

# %%
#importing GridSearchCV library
from sklearn.model_selection import GridSearchCV

# %%
#setting parameters for tuning
grid_param=[{'criterion':["squared_error", "absolute_error", "poisson"],
           'min_samples_split':[2,2.5,3,3.5],
            'max_depth':[1,2,3,4],
            'max_features':['sqrt','log2',None],
            'bootstrap':[True,False]}]

# %%
grid=GridSearchCV(rf,param_grid=grid_param)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid=[{'bootstrap': [True, False],
#                           'criterion': ['squared_error', 'absolute_error',
#                                         'poisson'],
#                           'max_depth': [1, 2, 3, 4],
#                           'max_features': ['sqrt', 'log2', None],
#                           'min_samples_split': [2, 2.5, 3, 3.5]}])

# %%
#best parameters for tuning
grid.best_params_
# Out:
# {'bootstrap': False,
#  'criterion': 'absolute_error',
#  'max_depth': 1,
#  'max_features': None,
#  'min_samples_split': 2}

# %%
#using best parameters to train

rf1=RandomForestRegressor(criterion='absolute_error'
                          ,min_samples_split=2,
                          max_depth=1,max_features=None,bootstrap=False)

# %%
rf1.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=False, criterion='absolute_error', max_depth=1,
#                       max_features=None)

# %%
# since thge model is already trained, below code will help to predict based on train and test data

y_pred=rf1.predict(x_train) 

pred=rf1.predict(x_test)

#printing r2 score for testing and training models.
#r2 score give value of how good the model has studied and learnt the data

print(f'training R2 score:{r2_score(y_train,y_pred)*100:.2f}%')
print(f'testing R2 score:{r2_score(y_test,pred)*100:.2f}%')
# Out:
# training R2 score:61.44%
# testing R2 score:91.28%

# %%
#cross validation score
print('Cross Validation Score for Random forest tuned model :- ',((cross_val_score(rf1,x_scaled,Y,cv=19).mean())*100))
# Out:
# Cross Validation Score for Random forest tuned model :-  -10.033970065442322

# %%
#finding mean absolute error() for above model(MAE)
print('mean absolute error',mean_absolute_error(y_test,pred))

#finding root mean_squared_error(RMSE)
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absolute error 398.8736890104879
# root mean squared error 2462.6880432853877

# %%
#plotting scatter plot for predicted vs actual

plt.scatter(y_test,pred)
plt.plot(y_test,y_test,color='r')
plt.xlabel('actual average cost for 2')
plt.ylabel('predicted average cost for 2')
plt.title('actual vs model predicted')
plt.show()

# %% [markdown]
# **SInce the tuned model gives less testing and training accuracy, hence saving original random forest model.**

# %% [markdown]
# # Saving the model using pickle

# %%
import pickle

# %%
pickle.dump(rf,open('zomato_average_cost_rf','wb'))

# %% [markdown]
# # Going forward with 2nd part by taking Price range as label.

# %%
df.head()
# Out:
#    Country  Restaurant Name  City  Locality Verbose  Longitude   Latitude  \
# 0        3             3201     1                17  78.011544  27.161661
# 1        3             5261     1                17   0.000000   0.000000
# 2        3             6919     1                17  78.011608  27.160832
# 3        3             1637     1               205  77.998092  27.195928
# 4        3             4922     1               205  78.007553  27.201725
#
#    Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0      1514                   850         4                  0
# 1      1514                   700         4                  0
# 2      1306                   500         4                  0
# 3      1645                   400         4                  0
# 4      1373                  1000         4                  0
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# ...

# %%
df.shape
# Out:
# (9551, 17)

# %% [markdown]
# # Checking for outliers in dataset

# %%
features=['Longitude','Latitude','Aggregate rating','Votes','Average Cost for two']

# %%
plt.figure(figsize=(15,15))
plotnumber=1

for column in features:
    if plotnumber<=6:
        ax=plt.subplot(3,2,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# - All the columns plotted shows presence of Outliers, Hence removing them using Zscore method.

# %% [markdown]
# # Removal of outliers using z-score method

# %%
z_score=zscore(df[['Longitude','Latitude','Aggregate rating','Votes','Average Cost for two']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)

# %%
df=df[filtering_entry]

# %%
data.shape
# Out:
# (7581, 17)

# %% [markdown]
# # Data loss after removing outliers

# %%
# data loss percentage 
data_loss=((9551-7581)/7581)*100
print(f'data loss in percent after removing outliers is: {data_loss}%')
# Out:
# data loss in percent after removing outliers is: 25.98601767576837%

# %% [markdown]
# # Since the data loss is more than 10% , I wont be dropping any outliers from this dataset.

# %%
data.shape
# Out:
# (9551, 17)

# %% [markdown]
# # Checking for skewness in dataset

# %%
df[features].skew()
# Out:
# Longitude               -2.807328
# Latitude                -3.081635
# Aggregate rating        -0.954130
# Votes                    8.807637
# Average Cost for two    35.477915
# dtype: float64

# %%
plt.figure(figsize=(15,15))
plotnumber=1

for column in features:
    if plotnumber<=6:
        ax=plt.subplot(3,2,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Removing skewness using power transform method

# %%
scaler=PowerTransformer(method='yeo-johnson') #using yeo-johnson method to transform

#transforming the data
df[features]=scaler.fit_transform(df[features])


#printing features to check for skewness
df[features].skew()
# Out:
# Longitude              -0.803832
# Latitude               -0.293200
# Aggregate rating       -0.610806
# Votes                  -0.004029
# Average Cost for two    0.142365
# dtype: float64

# %% [markdown]
# # Using Select KBest feature selection method to find best features to build a model.

# %%
X=df.drop(['Price range'],axis=1)
Y=df['Price range']

best_features=SelectKBest(score_func=f_classif,k=14)
fit=best_features.fit(X,Y)
df_scores=pd.DataFrame(fit.scores_)
df_columns=pd.DataFrame(X.columns)
feature_score=pd.concat([df_columns,df_scores],axis=1)
feature_score.columns=['Feature Name','Score']
print(feature_score.nlargest(14,'Score'))
# Out:
#             Feature Name        Score
# 15                 Votes  1395.031498
# 9      Has Table booking  1334.321846
# 7   Average Cost for two  1027.831359
# 12      Aggregate rating   939.802875
# 10   Has Online delivery   259.996134
# 14           Rating text   136.495966
# 0                Country   109.570337
# 3       Locality Verbose    67.880957
# 13          Rating color    64.379889
# 2                   City    50.204078
# 5               Latitude    49.657652
# 8               Currency    24.250267
# 1        Restaurant Name    12.566293
# 4              Longitude     7.573018

# %%
x=df[['Restaurant Name','Country','Currency','City','Average Cost for two', 'Locality Verbose','Longitude','Latitude','Has Table booking', 'Has Online delivery', 'Aggregate rating', 'Rating color', 'Rating text','Votes']]

# %%
#Checking for value counts in label data

Y.value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# From above output it can be seen that there are total 4 categories and 3 of them are oversampled.
# # Hence applying SMOTE to remove Oversampling

# %%
#importing library for SMOTE
from imblearn.over_sampling import SMOTE
from collections import Counter

sm=SMOTE()

# %%
x_new,y_new=sm.fit_resample(x,Y)
print('The no. of classes before fit',format(Counter(Y)))
print('The no. of classes after fit',format(Counter(y_new)))
# Out:
# The no. of classes before fit Counter({1: 4444, 2: 3113, 3: 1408, 4: 586})
# The no. of classes after fit Counter({3: 4444, 2: 4444, 4: 4444, 1: 4444})

# %% [markdown]
# # Scaling the data

# %%
#Standardizing data

scaler=StandardScaler()

#scaling features

x_scaled=scaler.fit_transform(x_new)

# %% [markdown]
# # Model Buiding part

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,f1_score

# %%
#saving models in variables

rf=RandomForestClassifier()
ab=AdaBoostClassifier()
dt=DecisionTreeClassifier()
gbdt=GradientBoostingClassifier()

# %% [markdown]
# - The scaled features are saved in **x_scaled** and label data in **y_new**.

# %%
#finding best random state for model
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y_new,test_size=0.25,random_state=i)
    rf.fit(x_train,y_train)
    y_pred=rf.predict(x_train)
    pred=rf.predict(x_test)
    print('training accuracy is ',(accuracy_score(y_train,y_pred)*100),' for random state ',i)
    print('testing accuracy is ',(accuracy_score(y_test,pred)*100),' for random state ',i)
    print('\n')
# Out:
# training accuracy is  100.0  for random state  0
# testing accuracy is  96.33213321332134  for random state  0
#
#
# training accuracy is  100.0  for random state  1
# testing accuracy is  96.5121512151215  for random state  1
#
#
# training accuracy is  100.0  for random state  2
# testing accuracy is  95.76957695769576  for random state  2
#
#
# training accuracy is  100.0  for random state  3
# testing accuracy is  97.0972097209721  for random state  3
#
#
# training accuracy is  100.0  for random state  4
# testing accuracy is  96.33213321332134  for random state  4
#
#
# training accuracy is  100.0  for random state  5
# testing accuracy is  96.26462646264626  for random state  5
#
#
# training accuracy is  100.0  for random state  6
# testing accuracy is  96.35463546354636  for random state  6
#
#
# training accuracy is  100.0  for random state  7
# testing accuracy is  96.55715571557155  for random state  7
#
#
# training accuracy is  100.0  for random state  8
# ...

# %% [markdown]
# **Taking random state as 7 for model building.**

# %%
#initiating train test split thereafter model training
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y_new,test_size=0.25,random_state=7)

def metric_score(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(x_train)
        print('-----Training score-----')
        print(f'Accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%')
    elif train==False:
        pred=clf.predict(x_test)
        print('-----Testing score-----')
        print(f'Accuracy score:{accuracy_score(y_test,pred)*100:.2f}%')
        print('classification report \n',classification_report (y_test,pred))
        print('confusion matrix ',confusion_matrix(y_test,pred))
        print('F1 Score ',f1_score(y_test,pred,average='micro'))

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#passing the function
metric_score(rf,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(rf,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:100.00%
# -----Testing score-----
# Accuracy score:96.62%
# classification report
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      1.00      1102
#            2       0.98      0.96      0.97      1112
#            3       0.93      0.94      0.94      1081
#            4       0.96      0.97      0.96      1149
#
#     accuracy                           0.97      4444
#    macro avg       0.97      0.97      0.97      4444
# weighted avg       0.97      0.97      0.97      4444
#
# confusion matrix  [[1095    7    0    0]
#  [   2 1068   41    1]
#  [   0   15 1016   50]
#  [   0    1   33 1115]]
# F1 Score  0.9662466246624662

# %%
#finding best value for cv in provided range
for i in range(2,20):
    cv_score=cross_val_score(rf,x_scaled,y_new,cv=i)
    cv=cv_score.mean()
    print('At cv:-',i)
    print('cross validation score:- ',cv*100)
# Out:
# At cv:- 2
# cross validation score:-  87.16246624662467
# At cv:- 3
# cross validation score:-  89.25540266189711
# At cv:- 4
# cross validation score:-  89.48019801980197
# At cv:- 5
# cross validation score:-  91.2637803185994
# At cv:- 6
# cross validation score:-  91.19022448748763
# At cv:- 7
# cross validation score:-  93.54714596280034
# At cv:- 8
# cross validation score:-  93.45747074707471
# At cv:- 9
# cross validation score:-  93.79486040645266
# At cv:- 10
# cross validation score:-  93.90110669199552
# At cv:- 11
# cross validation score:-  93.61498649864987
# At cv:- 12
# cross validation score:-  93.89611719962835
# At cv:- 13
# cross validation score:-  94.24472191865256
# At cv:- 14
# cross validation score:-  93.57526231206916
# At cv:- 15
# cross validation score:-  93.79492579864
# At cv:- 16
# cross validation score:-  94.13816381638163
# At cv:- 17
# cross validation score:-  93.83303582624008
# At cv:- 18
# cross validation score:-  93.72619469204017
# ...

# %%
#cross validation score
print('Cross Validation Score for Random Forest model :- ',((cross_val_score(rf,x_scaled,y_new,cv=13).mean())*100))
# Out:
# Cross Validation Score for Random Forest model :-  93.99717277080308

# %% [markdown]
# # Adaboost Classifier

# %%
ab.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
#passing the function
metric_score(ab,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(ab,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:66.87%
# -----Testing score-----
# Accuracy score:67.60%
# classification report
#                precision    recall  f1-score   support
#
#            1       0.99      0.96      0.98      1102
#            2       0.53      0.93      0.67      1112
#            3       0.28      0.11      0.16      1081
#            4       0.80      0.69      0.74      1149
#
#     accuracy                           0.68      4444
#    macro avg       0.65      0.67      0.64      4444
# weighted avg       0.65      0.68      0.64      4444
#
# confusion matrix  [[1060   41    1    0]
#  [   6 1036   46   24]
#  [   0  788  120  173]
#  [   0  101  260  788]]
# F1 Score  0.675967596759676

# %%
#cross validation score
print('Cross Validation Score for AdaBoost model :- ',((cross_val_score(ab,x_scaled,y_new,cv=13).mean())*100))
# Out:
# Cross Validation Score for AdaBoost model :-  65.48748355047204

# %% [markdown]
# # Decision Tree

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#passing the function
metric_score(dt,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(dt,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:100.00%
# -----Testing score-----
# Accuracy score:94.76%
# classification report
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      1.00      1102
#            2       0.97      0.96      0.96      1112
#            3       0.88      0.92      0.90      1081
#            4       0.94      0.92      0.93      1149
#
#     accuracy                           0.95      4444
#    macro avg       0.95      0.95      0.95      4444
# weighted avg       0.95      0.95      0.95      4444
#
# confusion matrix  [[1095    6    0    1]
#  [   2 1062   45    3]
#  [   0   23  996   62]
#  [   0    4   87 1058]]
# F1 Score  0.9475697569756976

# %%
#cross validation score
print('Cross Validation Score for Decision Tree model :- ',((cross_val_score(dt,x_scaled,y_new,cv=13).mean())*100))
# Out:
# Cross Validation Score for Decision Tree model :-  91.51095763154439

# %% [markdown]
# # Gradient Boosting

# %%
gbdt.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
#passing the function
metric_score(gbdt,x_train,x_test,y_train,y_test,train=True) # this is for training score

metric_score(gbdt,x_train,x_test,y_train,y_test,train=False) # this is for testing score
# Out:
# -----Training score-----
# Accuracy score:95.80%
# -----Testing score-----
# Accuracy score:94.22%
# classification report
#                precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99      1102
#            2       0.97      0.94      0.96      1112
#            3       0.88      0.90      0.89      1081
#            4       0.93      0.93      0.93      1149
#
#     accuracy                           0.94      4444
#    macro avg       0.94      0.94      0.94      4444
# weighted avg       0.94      0.94      0.94      4444
#
# confusion matrix  [[1101    1    0    0]
#  [  15 1044   48    5]
#  [   1   28  972   80]
#  [   0    0   79 1070]]
# F1 Score  0.9421692169216922

# %%
#cross validation score
print('Cross Validation Score for Decision Tree model :- ',((cross_val_score(gbdt,x_scaled,y_new,cv=13).mean())*100))
# Out:
# Cross Validation Score for Decision Tree model :-  92.16319642916494

# %% [markdown]
# # Dataframe showing training, testing, F1 score and Cross validation scores with respect to different models

# %%
column=pd.DataFrame({'Model':['Random Forests','AdaBoost','Decision Trees','Gradient Boosted Tees',],
                    'Training scores':[100,66.87,100,95.80],
                    'Testing scores':[96.62,67.60,94.76,94.22],
                    'Cross validation score':[93.99,65.48,91.51,92.16],
                    'F1 score':[96.62,67.59,94.75,94.21]})
column
# Out:
#                    Model  Training scores  Testing scores  \
# 0         Random Forests           100.00           96.62
# 1               AdaBoost            66.87           67.60
# 2         Decision Trees           100.00           94.76
# 3  Gradient Boosted Tees            95.80           94.22
#
#    Cross validation score  F1 score
# 0                   93.99     96.62
# 1                   65.48     67.59
# 2                   91.51     94.75
# 3                   92.16     94.21

# %% [markdown]
# - Looking at the dataframe above I can say that Random Forest,Decision Tree and Gradient Boosted Tees;all 3 models show great training and testing accuracy. But Random Forest has good training, better testing accuracy than other 2 models.
# # Hence Random Forest Classifier model will be hyperparameter tuned.

# %%
#importing library for for grid search CV

from sklearn.model_selection import GridSearchCV

# %%
grid_param=[{'n_estimators':[10,20,30,40],
           'max_depth':[1,2,3,4,5],
           'criterion':['gini','entropy','log_loss'],
            'min_samples_split':(2,3,4,5),
            'max_features':["sqrt", "log2", None]}]

# %%
#saving model in variable
grid=GridSearchCV(RandomForestClassifier(),param_grid=grid_param)

# %%
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid=[{'criterion': ['gini', 'entropy', 'log_loss'],
#                           'max_depth': [1, 2, 3, 4, 5],
#                           'max_features': ['sqrt', 'log2', None],
#                           'min_samples_split': (2, 3, 4, 5),
#                           'n_estimators': [10, 20, 30, 40]}])

# %%
#best parameters for tuning
grid.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 5,
#  'max_features': None,
#  'min_samples_split': 2,
#  'n_estimators': 20}

# %%
#using best parameters to train 
rf1=RandomForestClassifier(n_estimators=20,
                           max_depth=5,
                           criterion='log_loss',
                           min_samples_split=2,
                           max_features=None)

# %%
rf1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=5, max_features=None,
#                        n_estimators=20)

# %%
#passing the function
metric_score(rf1,x_train,x_test,y_train,y_test,train=True) #for training data
metric_score(rf1,x_train,x_test,y_train,y_test,train=False) # for testing data
# Out:
# -----Training score-----
# Accuracy score:91.26%
# -----Testing score-----
# Accuracy score:90.98%
# classification report
#                precision    recall  f1-score   support
#
#            1       0.98      1.00      0.99      1102
#            2       0.94      0.93      0.94      1112
#            3       0.90      0.78      0.83      1081
#            4       0.83      0.93      0.88      1149
#
#     accuracy                           0.91      4444
#    macro avg       0.91      0.91      0.91      4444
# weighted avg       0.91      0.91      0.91      4444
#
# confusion matrix  [[1100    2    0    0]
#  [  20 1036   17   39]
#  [   1   60  840  180]
#  [   0    4   78 1067]]
# F1 Score  0.9097659765976598

# %%
#cross validation score
print('Cross Validation Score for tuned Random Forest Classifier model :- ',((cross_val_score(rf1,x_scaled,y_new,cv=13).mean())*100))
# Out:
# Cross Validation Score for tuned Random Forest Classifier model :-  89.55819422602235

# %% [markdown]
# Original random forest model had seen more data with better test score.
# # Hence saving original Random Forest model

# %% [markdown]
# # Saving the model using pickle

# %%
pickle.dump(rf,open('price_range_zomato_rf','wb'))
